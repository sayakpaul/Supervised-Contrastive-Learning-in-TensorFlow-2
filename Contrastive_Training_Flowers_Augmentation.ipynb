# %% [markdown]
# <a href="https://colab.research.google.com/github/sayakpaul/Supervised-Contrastive-Learning-in-TensorFlow-2/blob/master/Contrastive_Training_Flowers_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## References:
# - https://arxiv.org/pdf/2004.11362.pdf
# - https://towardsdatascience.com/contrastive-loss-for-supervised-classification-224ae35692e7

# %% [markdown]
# ## Initial setup

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
# !nvidia-smi
# Out:
# Thu May 28 09:39:26 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install --upgrade https://github.com/wandb/client/archive/feature/code-save.zip -q
import wandb
wandb.login()

# %%
# !wget https://raw.githubusercontent.com/wangz10/contrastive_loss/master/losses.py

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tqdm.notebook import tqdm
from wandb.keras import WandbCallback
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import losses
import time

tf.random.set_seed(666)
np.random.seed(666)

tfds.disable_progress_bar()

# %%
import os
os.environ['WANDB_DISABLE_CODE'] = 'True'

# %% [markdown]
# ## Flowers dataset

# %%
# Gather Flowers dataset
train_ds, validation_ds = tfds.load(
    "tf_flowers",
    split=["train[:85%]", "train[85%:]"],
    as_supervised=True
)

# %%
# Visualization
plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(train_ds.take(9)):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image)
  plt.title(int(label))
  plt.axis("off")

# %% [markdown]
# ## Data pipeline

# %%
IMG_SHAPE = 128
BS = 64
AUTO = tf.data.experimental.AUTOTUNE

# Referred from: https://arxiv.org/pdf/2002.05709.pdf (Appendxi A 
# corresponding GitHub: https://github.com/google-research/simclr/)
# I did not use all the augmentation policies proposed in the above paper

@tf.function
def custom_augment(image, label):        
    # Random flips
    image = random_apply(tf.image.flip_left_right, image, p=0.5)
    
    # Randomly apply transformation (color distortions) with probability p.
    image = random_apply(color_jitter, image, p=0.4)
    image = random_apply(color_drop, image, p=0.2)

    return (image, label)

@tf.function
def color_jitter(x, s=0.5):
    # one can also shuffle the order of following augmentations
    # each time they are applied.
    x = tf.image.random_brightness(x, max_delta=0.8*s)
    x = tf.image.random_contrast(x, lower=1-0.8*s, upper=1+0.8*s)
    x = tf.image.random_saturation(x, lower=1-0.8*s, upper=1+0.8*s)
    x = tf.image.random_hue(x, max_delta=0.2*s)
    x = tf.clip_by_value(x, 0, 1)
    return x

@tf.function
def color_drop(x):
    x = tf.image.rgb_to_grayscale(x)
    x = tf.tile(x, [1, 1, 3])
    return x

@tf.function
def random_apply(func, x, p):
    return tf.cond(
        tf.less(tf.random.uniform([], minval=0, maxval=1, dtype=tf.float32),
                tf.cast(p, tf.float32)),
        lambda: func(x),
        lambda: x)

@tf.function
def preprocess_image(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, (IMG_SHAPE, IMG_SHAPE))

    return (image, label)

train_ds = (
    train_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .shuffle(100)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BS)
    .prefetch(AUTO)
)

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for n in range(25):
    ax = plt.subplot(5, 5, n+1)
    plt.imshow(image_batch[n])
    plt.title(label_batch[n].numpy())
    plt.axis('off')

# %% [markdown]
# ## Model building

# %%
# Reference: https://github.com/wangz10/contrastive_loss/blob/master/model.py
class UnitNormLayer(tf.keras.layers.Layer):
    '''Normalize vectors (euclidean norm) in batch to unit hypersphere.
    '''
    def __init__(self):
        super(UnitNormLayer, self).__init__()

    def call(self, input_tensor):
        norm = tf.norm(input_tensor, axis=1)
        return input_tensor / tf.reshape(norm, [-1, 1])

# %%
# Encoder Network
def encoder_net():
	inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))
	normalization_layer = UnitNormLayer()

	encoder = tf.keras.applications.ResNet50(weights=None, include_top=False)
	encoder.trainable = True

	embeddings = encoder(inputs, training=True)
	embeddings = GlobalAveragePooling2D()(embeddings)
	norm_embeddings = normalization_layer(embeddings)

	encoder_network = Model(inputs, norm_embeddings)

	return encoder_network

# Projector Network
def projector_net():
	projector = tf.keras.models.Sequential([
		Dense(128, activation="relu"),
		UnitNormLayer()
	])

	return projector

# %% [markdown]
# ## Running forward passes through single images

# %%
encoder_r = encoder_net()
projector_z = projector_net()

images, _ = next(iter(train_ds))
r = encoder_r(tf.expand_dims(images[0], 0))
z = projector_z(r)

print(tf.shape(r))
print(tf.shape(z))
# Out:
# tf.Tensor([   1 2048], shape=(2,), dtype=int32)
# tf.Tensor([  1 128], shape=(2,), dtype=int32)

# %% [markdown]
# ## Training the encoder and the projector

# %%
decay_steps = 1000
lr_decayed_fn = tf.keras.experimental.CosineDecay(
    initial_learning_rate=0.001, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.Adam(lr_decayed_fn)

# %%
encoder_r = encoder_net()
projector_z = projector_net()

@tf.function
def train_step(images, labels):
	with tf.GradientTape() as tape:
		r = encoder_r(images, training=True)
		z = projector_z(r, training=True)
		loss = losses.max_margin_contrastive_loss(z, labels, metric='cosine')

	gradients = tape.gradient(loss, 
		encoder_r.trainable_variables + projector_z.trainable_variables)
	optimizer.apply_gradients(zip(gradients, 
		encoder_r.trainable_variables + projector_z.trainable_variables))

	return loss

# %%
wandb.init(project="scl", entity="authors", id="supervised-contrastive-flowers-adam-simaug")
EPOCHS = 60
LOG_EVERY = 10
train_loss_results = []

start = time.time()
for epoch in tqdm(range(EPOCHS)):	
	epoch_loss_avg = tf.keras.metrics.Mean()
	
	for (images, labels) in train_ds:
		loss = train_step(images, labels)
		epoch_loss_avg.update_state(loss) 

	train_loss_results.append(epoch_loss_avg.result())
	wandb.log({"supervised_contrastive_loss": epoch_loss_avg.result()})

	if epoch % LOG_EVERY == 0:
		print("Epoch: {} Loss: {:.3f}".format(epoch, epoch_loss_avg.result()))

end = time.time()
wandb.log({"training_time": end - start})

with plt.xkcd():
    plt.plot(train_loss_results)
    plt.title("Supervised Contrastive Loss")
    plt.show()
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/authors/scl" target="_blank">https://app.wandb.ai/authors/scl</a><br/>
#                 Run page: <a href="https://app.wandb.ai/authors/scl/runs/supervised-contrastive-flowers-adam-simaug" target="_blank">https://app.wandb.ai/authors/scl/runs/supervised-contrastive-flowers-adam-simaug</a><br/>
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# Epoch: 0 Loss: 0.244
# Epoch: 10 Loss: 0.167
# Epoch: 20 Loss: 0.143
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# WARNING:wandb.util:requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream. args: ('https://api.wandb.ai/files/authors/scl/supervised-contrastive-flowers-adam-simaug/file_stream',), kwargs: {'json': {'files': {'wandb-events.jsonl': {'offset': 13, 'content': ['{"system.gpu.0.gpu": 89.87, "system.gpu.0.memory": 56.87, "system.gpu.0.memoryAllocated": 73.65, "system.gpu.0.temp": 68.67, "system.gpu.0.powerWatts": 146.22, "system.gpu.0.powerPercent": 98.14, "system.cpu": 42.45, "system.memory": 18.1, "system.disk": 48.8, "system.proc.memory.availableMB": 10661.4, "system.proc.memory.rssMB": 2561.7, "system.proc.memory.percent": 19.67, "system.proc.cpu.threads": 144.0, "system.network.sent": 337449, "system.network.recv": 386878, "_wandb": true, "_timestamp": 1590659858, "_runtime": 1079}\n']}, 'wandb-history.jsonl': {'offset': 17, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_runtime": 1061.5252690315247, "_timestamp": 1590659840.450881, "_step": 17}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"supervised_contrastive_loss": 0.1470165103673935, "_timestamp": 1590659840.450881, "_step": 17, "_runtime": 1061.5252690315247}\n']}}}}
# Epoch: 30 Loss: 0.144
# Epoch: 40 Loss: 0.144
# Epoch: 50 Loss: 0.143

# %% [markdown]
# ## Supervised training

# %%
validation_ds = (
    validation_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .shuffle(100)
    .batch(BS)
    .prefetch(AUTO)
)

# %%
def supervised_model():
	inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))
	encoder_r.trainable = False

	r = encoder_r(inputs, training=False)
	outputs = Dense(5)(r)

	supervised_model = Model(inputs, outputs)

	return supervised_model

# %%
supervised_classifier = supervised_model()

supervised_classifier.compile(optimizer=tf.keras.optimizers.Adam(),
	loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
	metrics=["accuracy"])

wandb.init(project="scl", entity="authors", id="flowers-fully-supervised-simaug")
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2,
	restore_best_weights=True, verbose=2)

supervised_classifier.fit(train_ds,
	validation_data=validation_ds,
	epochs=50,
	callbacks=[WandbCallback(), es])
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/authors/scl" target="_blank">https://app.wandb.ai/authors/scl</a><br/>
#                 Run page: <a href="https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug" target="_blank">https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug</a><br/>
# Epoch 1/50
# 49/49 [==============================] - 11s 231ms/step - loss: 1.4231 - accuracy: 0.5391 - val_loss: 1.1734 - val_accuracy: 0.6600
# Epoch 2/50
# 49/49 [==============================] - 11s 221ms/step - loss: 1.1734 - accuracy: 0.5811 - val_loss: 0.9741 - val_accuracy: 0.6764
# Epoch 3/50
# 49/49 [==============================] - 11s 215ms/step - loss: 1.0744 - accuracy: 0.5968 - val_loss: 0.8889 - val_accuracy: 0.6782
# Epoch 4/50
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0510 - accuracy: 0.5875 - val_loss: 0.8506 - val_accuracy: 0.6800
# Epoch 5/50
# 49/49 [==============================] - 10s 214ms/step - loss: 1.0276 - accuracy: 0.5984 - val_loss: 0.8306 - val_accuracy: 0.6727
# Epoch 6/50
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0198 - accuracy: 0.6016 - val_loss: 0.8178 - val_accuracy: 0.6727
# Epoch 7/50
# 49/49 [==============================] - 11s 219ms/step - loss: 1.0023 - accuracy: 0.6019 - val_loss: 0.8087 - val_accuracy: 0.6782
# Epoch 8/50
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0038 - accuracy: 0.5990 - val_loss: 0.8045 - val_accuracy: 0.6764
# Epoch 9/50
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0100 - accuracy: 0.5920 - val_loss: 0.8008 - val_accuracy: 0.6745
# Epoch 10/50
# 49/49 [==============================] - 11s 217ms/step - loss: 0.9944 - accuracy: 0.5990 - val_loss: 0.7968 - val_accuracy: 0.6727
# Epoch 11/50
# 49/49 [==============================] - 11s 216ms/step - loss: 0.9985 - accuracy: 0.5965 - val_loss: 0.7928 - val_accuracy: 0.6745
# Epoch 12/50
# 49/49 [==============================] - 11s 216ms/step - loss: 1.0000 - accuracy: 0.6026 - val_loss: 0.7910 - val_accuracy: 0.6709
# Epoch 13/50
# 49/49 [==============================] - 10s 205ms/step - loss: 0.9902 - accuracy: 0.5965 - val_loss: 0.7930 - val_accuracy: 0.6727
# Epoch 14/50
# 49/49 [==============================] - 11s 214ms/step - loss: 0.9965 - accuracy: 0.5984 - val_loss: 0.7902 - val_accuracy: 0.6691
# Epoch 15/50
# 49/49 [==============================] - 10s 213ms/step - loss: 0.9858 - accuracy: 0.6096 - val_loss: 0.7893 - val_accuracy: 0.6691
# Epoch 16/50
# 49/49 [==============================] - 11s 216ms/step - loss: 0.9885 - accuracy: 0.5978 - val_loss: 0.7866 - val_accuracy: 0.6727
# Epoch 17/50
# 49/49 [==============================] - 10s 204ms/step - loss: 0.9835 - accuracy: 0.6038 - val_loss: 0.7877 - val_accuracy: 0.6727
# Epoch 18/50
# 49/49 [==============================] - ETA: 0s - loss: 0.9800 - accuracy: 0.6038Restoring model weights from the end of the best epoch.
# 49/49 [==============================] - 10s 206ms/step - loss: 0.9800 - accuracy: 0.6038 - val_loss: 0.7867 - val_accuracy: 0.6745
# Epoch 00018: early stopping

# %% [markdown]
# Training stabilizes a bit with augmentation but we are not getting as good results as shown [in this notebook](https://github.com/sayakpaul/Supervised-Contrastive-Learning-in-TensorFlow-2/blob/master/Contrastive_Training_Flowers.ipynb). **Note** that we are using the same augmentation policy in the training dataset like the way we did in the stage-1 of the framework.

# %% [markdown]
# ## SGD + Cosine Decay + `EarlyStopping`

# %%
decay_steps = 1000
lr_decayed_fn = tf.keras.experimental.CosineDecay(
    initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

supervised_classifier = supervised_model()

supervised_classifier.compile(optimizer=optimizer,
	loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
	metrics=["accuracy"])

wandb.init(project="scl", entity="authors", id="flowers-fully-supervised-simaug-sgd")
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2,
	restore_best_weights=True, verbose=2)

supervised_classifier.fit(train_ds,
	validation_data=validation_ds,
	epochs=50,
	callbacks=[WandbCallback(), es])
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/authors/scl" target="_blank">https://app.wandb.ai/authors/scl</a><br/>
#                 Run page: <a href="https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug-sgd" target="_blank">https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug-sgd</a><br/>
# Epoch 1/50
# 49/49 [==============================] - 12s 239ms/step - loss: 1.5500 - accuracy: 0.3657 - val_loss: 1.4792 - val_accuracy: 0.5818
# Epoch 2/50
# 49/49 [==============================] - 11s 222ms/step - loss: 1.4503 - accuracy: 0.5429 - val_loss: 1.3736 - val_accuracy: 0.6255
# Epoch 3/50
# 49/49 [==============================] - 11s 219ms/step - loss: 1.3738 - accuracy: 0.5712 - val_loss: 1.2878 - val_accuracy: 0.6527
# Epoch 4/50
# 49/49 [==============================] - 11s 220ms/step - loss: 1.3137 - accuracy: 0.5782 - val_loss: 1.2196 - val_accuracy: 0.6600
# Epoch 5/50
# 49/49 [==============================] - 11s 220ms/step - loss: 1.2667 - accuracy: 0.5856 - val_loss: 1.1659 - val_accuracy: 0.6600
# Epoch 6/50
ss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
	metrics=["accuracy"])

wandb.init(project="scl", entity="authors", id="flowers-fully-supervised-simaug-adam-high-lr")
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2,
	restore_best_weights=True, verbose=2)

supervised_classifier.fit(train_ds,
	validation_data=validation_ds,
	epochs=50,
	callbacks=[WandbCallback(), es])
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/authors/scl" target="_blank">https://app.wandb.ai/authors/scl</a><br/>
#                 Run page: <a href="https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug-adam-high-lr" target="_blank">https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug-adam-high-lr</a><br/>
# Epoch 1/50
# 49/49 [==============================] - 12s 235ms/step - loss: 1.2271 - accuracy: 0.5596 - val_loss: 0.8741 - val_accuracy: 0.6527
# Epoch 2/50
# 49/49 [==============================] - 10s 204ms/step - loss: 1.1363 - accuracy: 0.5702 - val_loss: 0.8982 - val_accuracy: 0.6400
# Epoch 3/50
# 49/49 [==============================] - ETA: 0s - loss: 1.1300 - accuracy: 0.5651Restoring model weights from the end of the best epoch.
# 49/49 [==============================] - 10s 205ms/step - loss: 1.1300 - accuracy: 0.5651 - val_loss: 0.9112 - val_accuracy: 0.6582
# Epoch 00003: early stopping

# %% [markdown]
# ## Adam + Cosine Decay + **No** `EarlyStopping`

# %%
decay_steps = 1000
lr_decayed_fn = tf.keras.experimental.CosineDecay(
    initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.Adam(lr_decayed_fn)

supervised_classifier = supervised_model()

supervised_classifier.compile(optimizer=tf.keras.optimizers.Adam(),
	loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
	metrics=["accuracy"])

wandb.init(project="scl", entity="authors", id="flowers-fully-supervised-simaug-no-es")

supervised_classifier.fit(train_ds,
	validation_data=validation_ds,
	epochs=100,
	callbacks=[WandbCallback()])
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/authors/scl" target="_blank">https://app.wandb.ai/authors/scl</a><br/>
#                 Run page: <a href="https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug-no-es" target="_blank">https://app.wandb.ai/authors/scl/runs/flowers-fully-supervised-simaug-no-es</a><br/>
# Epoch 1/100
# 49/49 [==============================] - 11s 229ms/step - loss: 1.4129 - accuracy: 0.5596 - val_loss: 1.1669 - val_accuracy: 0.6582
# Epoch 2/100
# 49/49 [==============================] - 11s 222ms/step - loss: 1.1734 - accuracy: 0.5904 - val_loss: 0.9704 - val_accuracy: 0.6727
# Epoch 3/100
# 49/49 [==============================] - 10s 213ms/step - loss: 1.0690 - accuracy: 0.6003 - val_loss: 0.8877 - val_accuracy: 0.6782
# Epoch 4/100
# 49/49 [==============================] - 10s 214ms/step - loss: 1.0457 - accuracy: 0.5962 - val_loss: 0.8492 - val_accuracy: 0.6818
# Epoch 5/100
# 49/49 [==============================] - 11s 215ms/step - loss: 1.0214 - accuracy: 0.6026 - val_loss: 0.8272 - val_accuracy: 0.6836
# Epoch 6/100
# 49/49 [==============================] - 10s 213ms/step - loss: 0.9937 - accuracy: 0.6022 - val_loss: 0.8150 - val_accuracy: 0.6782
